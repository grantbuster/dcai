# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import json
import sys
import matplotlib.pyplot as plt

# %%
test = tf.keras.preprocessing.image_dataset_from_directory(
    './label_book/label_book',
    labels="inferred",
    label_mode="categorical",
    class_names=["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x"],
    shuffle=False,
    seed=123,
    batch_size=2,
    image_size=(32, 32),
)
# Out:
# Found 52 files belonging to 10 classes.

# %%
with open('./predictions.json', 'r') as f:
    out = json.load(f)
out = np.array(out) + 1
out
# Out:
# array([ 1,  1,  1,  1,  1,  2,  2,  8,  3,  2,  3,  3,  1,  2,  3,  3,  3,
#         4,  3,  4,  2,  5,  5,  1,  5,  5,  5,  6,  6,  6,  6,  6,  3,  3,
#         7,  7,  7,  8,  8,  8,  3,  8,  9,  9,  4,  2,  9, 10, 10, 10,  1,
#         9])

# %%
images = []
for element in test.unbatch():
    images.append(element[0])

# %%
for label, image in zip(out, images):
    plt.imshow(image.numpy().astype(np.uint8))
    plt.title(label)
    plt.show()
    plt.close()
